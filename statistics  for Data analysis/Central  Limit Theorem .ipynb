# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import random
random.seed=100
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\Banoth Sudhar\\Downloads\\archive(4)\\adult.csv")
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
sns.distplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
print('Number of rows: ', df.shape[0])
# Out:
# Number of rows:  48842

# %%
samples = random.sample(range(0, df.shape[0]), 50)

# %%
df.iloc[samples]
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 25512   33           Private   55176       7th-8th                4
# 22095   34           Private  265807  Some-college               10
# 46863   34           Private  209213       HS-grad                9
# 17431   25           Private  241626       HS-grad                9
# 47035   31           Private   33124   Prof-school               15
# 42937   21           Private  252024       HS-grad                9
# 39376   45  Self-emp-not-inc   77132  Some-college               10
# 1323    33           Private  392812       Masters               14
# 15092   17           Private  161123          12th                8
# 42255   35           Private  171327       HS-grad                9
# 33884   42         Local-gov  263871       HS-grad                9
# 3450    53           Private  185283       HS-grad                9
# 10834   45           Private  138342       HS-grad                9
# 36283   25           Private  197871     Bachelors               13
# 16541   36           Private  150042     Bachelors               13
# 40130   37           Private  348739     Bachelors               13
# 31216   23         State-gov   61743       5th-6th                3
# 43669   20           Private  471452  Some-college               10
# 1118    52           Private  173987       HS-grad                9
# 24601   57           Private  163047       HS-grad                9
# 39195   52           Private  443742  Some-college               10
# 9024    18      Self-emp-inc  357223          10th                6
# 5818    51           Private  194097  Some-college               10
# 17347   35           Private  199352   Prof-school               15
# 40994   68           Private  117236     Bachelors               13
# 27619   40           Private  145504       HS-grad                9
# 7878    32         State-gov   90409  Some-college               10
# 41341   22                 ?  154235  Some-college               10
# 36968   45           Private  278151       HS-grad                9
# 15228   36         Local-gov  102729       HS-grad                9
# 12126   23           Private  197613     Bachelors               13
# 22500   46           Private  175262    Assoc-acdm               12
# 7175    36           Private  152307       HS-grad                9
# 32498   51           Private  189762  Some-college               10
# 13930   35           Private  211494     Bachelors               13
# 23450   54           Private   94055     Bachelors               13
# 14619   39           Private   31053  Some-college               10
# 36543   44           Private  185798     Assoc-voc               11
# 14576   35           Private  184685  Some-college               10
# 30231   65         Local-gov  143570  Some-college               10
# 35330   28         Local-gov  335015       HS-grad                9
# 39348   34           Private  209297       HS-grad                9
# 14419   28           Private  291789       HS-grad                9
# 41505   32         Local-gov  169837    Assoc-acdm               12
# 40394   37           Private  105803       HS-grad                9
# 31764   39           Private  247733       HS-grad                9
# 29528   44           Private  102085  Some-college               10
# 12490   46         Local-gov  149551       HS-grad                9
# 1553    21           Private  180060  Some-college               10
# 1447    47      Self-emp-inc  308241     Bachelors               13
#
#            marital-status         occupation    relationship  \
# 25512  Married-civ-spouse       Craft-repair         Husband
# 22095           Separated       Craft-repair   Not-in-family
# 46863  Married-civ-spouse  Machine-op-inspct         Husband
# 17431       Never-married      Other-service       Own-child
# 47035       Never-married     Prof-specialty   Not-in-family
# 42937       Never-married  Handlers-cleaners  Other-relative
# 39376       Never-married              Sales   Not-in-family
# 1323   Married-civ-spouse    Exec-managerial         Husband
# 15092       Never-married      Other-service       Own-child
# 42255  Married-civ-spouse       Craft-repair         Husband
# 33884  Married-civ-spouse       Adm-clerical         Husband
# 3450   Married-civ-spouse       Craft-repair         Husband
# 10834  Married-civ-spouse       Craft-repair         Husband
# 36283       Never-married    Exec-managerial   Not-in-family
# 16541            Divorced     Prof-specialty       Own-child
# 40130  Married-civ-spouse     Prof-specialty         Husband
# 31216       Never-married   Transport-moving   Not-in-family
# 43669       Never-married      Other-service       Own-child
# 1118   Married-civ-spouse       Adm-clerical         Husband
# 24601  Married-civ-spouse    Exec-managerial            Wife
# 39195            Divorced    Exec-managerial   Not-in-family
# 9024        Never-married      Other-service       Own-child
# 5818   Married-civ-spouse    Exec-managerial            Wife
# 17347  Married-civ-spouse     Prof-specialty         Husband
# 40994  Married-civ-spouse    Exec-managerial         Husband
# 27619  Married-civ-spouse    Farming-fishing         Husband
# 7878        Never-married       Craft-repair       Own-child
# 41341  Married-civ-spouse                  ?            Wife
# 36968  Married-civ-spouse    Protective-serv         Husband
# 15228  Married-civ-spouse    Exec-managerial         Husband
# 12126       Never-married       Adm-clerical   Not-in-family
# 22500  Married-civ-spouse       Adm-clerical         Husband
# 7175   Married-civ-spouse       Adm-clerical         Husband
# 32498  Married-civ-spouse    Exec-managerial            Wife
# 13930       Never-married     Prof-specialty   Not-in-family
# 23450  Married-civ-spouse      Other-service         Husband
# 14619            Divorced              Sales       Unmarried
# 36543           Separated       Craft-repair  Other-relative
# 14576       Never-married       Adm-clerical  Other-relative
# 30231       Never-married     Prof-specialty   Not-in-family
# 35330  Married-civ-spouse       Craft-repair         Husband
# 39348       Never-married  Machine-op-inspct   Not-in-family
# 14419       Never-married  Machine-op-inspct       Unmarried
# 41505            Divorced    Exec-managerial   Not-in-family
# 40394  Married-civ-spouse       Craft-repair         Husband
# 31764            Divorced    Priv-house-serv       Unmarried
# 29528            Divorced       Adm-clerical  Other-relative
# 12490  Married-civ-spouse    Protective-serv         Husband
# 1553        Never-married  Machine-op-inspct       Own-child
# 1447             Divorced    Exec-managerial       Unmarried
#
#                      race  gender  capital-gain  capital-loss  hours-per-week  \
# 25512               White    Male             0             0              40
# 22095               White    Male             0             0              45
# 46863               Black    Male             0             0              40
# 17431               White    Male             0             0              30
# 47035               White  Female             0             0              99
# 42937               White    Male             0             0              20
# 39376               White    Male             0             0              55
# 1323                White    Male             0          1977              50
# 15092               White    Male             0             0              32
# 42255               White    Male             0             0              40
# 33884               White    Male             0             0               8
# 3450                White    Male             0             0              45
# 10834               White    Male             0             0              84
# 36283               White    Male             0             0              50
# 16541               White  Female             0             0              40
# 40130               White    Male             0             0              45
# 31216               White    Male             0             0              35
# 43669               White    Male             0             0              30
# 1118                White    Male             0             0              40
# 24601               White  Female             0             0              38
# 39195               White    Male             0             0              60
# 9024                White    Male             0             0              16
# 5818                White  Female             0             0              30
# 17347               White    Male             0          1977              80
# 40994               White    Male         20051             0              45
# 27619               Black    Male             0             0              40
# 7878                White    Male             0             0              20
# 41341               White  Female          3781             0              35
# 36968               White    Male             0             0              40
# 15228               White    Male             0             0              40
# 12126               White  Female             0             0              40
# 22500  Asian-Pac-Islander    Male             0             0              40
# 7175                White    Male          7298             0              55
# 32498               White  Female             0             0              15
# 13930               White    Male          8614             0              40
# 23450               White    Male             0             0              40
# 14619               White  Female             0             0              40
# 36543               White    Male             0             0              48
# 14576               Black  Female             0             0              40
# 30231               Black  Female             0             0              40
# 35330               White    Male             0             0              40
# 39348               Black    Male             0          2001              40
# 14419               Black  Female             0             0              50
# 41505               Black  Female             0             0              40
# 40394               White    Male          3103             0              45
# 31764               Black  Female             0             0              16
# 29528               White  Female             0             0              40
# 12490               White    Male          5013             0              50
# 1553                White    Male             0             0              40
# 1447                White  Female             0             0              60
#
#       native-country income
# 25512  United-States  <=50K
# 22095  United-States  <=50K
# 46863              ?  <=50K
# 17431  United-States  <=50K
# 47035  United-States  <=50K
# 42937         Mexico  <=50K
# 39376  United-States  <=50K
# 1323   United-States   >50K
# 15092  United-States  <=50K
# 42255  United-States  <=50K
# 33884  United-States  <=50K
# 3450   United-States   >50K
# 10834  United-States  <=50K
# 36283  United-States  <=50K
# 16541  United-States  <=50K
# 40130  United-States   >50K
# 31216  United-States  <=50K
# 43669  United-States  <=50K
# 1118   United-States   >50K
# 24601  United-States  <=50K
# 39195  United-States  <=50K
# 9024   United-States  <=50K
# 5818   United-States   >50K
# 17347  United-States   >50K
# 40994  United-States   >50K
# 27619  United-States  <=50K
# 7878   United-States  <=50K
# 41341  United-States  <=50K
# 36968  United-States  <=50K
# 15228  United-States  <=50K
# 12126  United-States  <=50K
# 22500          India  <=50K
# 7175   United-States   >50K
# 32498  United-States   >50K
# 13930              ?   >50K
# 23450  United-States  <=50K
# 14619  United-States  <=50K
# 36543  United-States   >50K
# 14576  United-States  <=50K
# 30231  United-States  <=50K
# 35330  United-States  <=50K
# 39348  United-States  <=50K
# 14419  United-States  <=50K
# 41505  United-States  <=50K
# 40394  United-States   >50K
# 31764  United-States  <=50K
# 29528  United-States  <=50K
# 12490  United-States  <=50K
# 1553   United-States  <=50K
# 1447   United-States   >50K

# %%
sample_mean = {}
means = []
for i in range(0, 100):
    samples = random.sample(range(0, df.shape[0]), 50)
    means.append(df.iloc[samples, 0].mean())

sample_mean['100sam_with_50ele'] = means

# %%
np.mean(sample_mean['100sam_with_50ele'])
# Out:
# 38.906600000000005

# %%
sns.distplot(np.array(sample_mean['100sam_with_50ele']))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
means = []
for i in range(0, 100):
    samples = random.sample(range(0, df.shape[0]), 100)
    means.append(df.iloc[samples, 0].mean())

sample_mean['100sam_with_100ele'] = means

# %%
np.mean(sample_mean['100sam_with_100ele'])
# Out:
# 38.6672

# %%
sns.distplot(np.array(sample_mean['100sam_with_100ele']))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
def fun(m_sample, n_element):
    means = []
    for i in range(0, m_sample):
        samples = random.sample(range(0, df.shape[0]), n_element)
        means.append(df.iloc[samples, 0].mean())
    return means

# %%
sample_mean = {}

sample_mean['100sam_with_50ele'] = fun(100, 50)
sample_mean['1000sam_with_50ele'] = fun(1000, 50)

sample_mean['100sam_with_100ele'] = fun(100, 100)
sample_mean['1000sam_with_100ele'] = fun(1000, 100)

sample_mean['100sam_with_1000ele'] = fun(100, 1000)
sample_mean['1000sam_with_1000ele'] = fun(1000, 1000)

# %%
plt.figure(figsize=(12, 6))
plt.subplots_adjust(hspace=0.4, wspace=0.7)

plt.subplot(2, 3, 1)
sns.distplot(np.array(sample_mean['100sam_with_50ele']))
plt.title('100sam_with_50ele')

plt.subplot(2, 3, 2)
sns.distplot(np.array(sample_mean['100sam_with_100ele']))
plt.title('100sam_with_100ele')

plt.subplot(2, 3, 3)
sns.distplot(np.array(sample_mean['100sam_with_1000ele']))
plt.title('100sam_with_1000ele')

plt.subplot(2, 3, 4)
sns.distplot(np.array(sample_mean['1000sam_with_50ele']))
plt.title('1000sam_with_50ele')

plt.subplot(2, 3, 5)
sns.distplot(np.array(sample_mean['1000sam_with_100ele']))
plt.title('1000sam_with_100ele')

plt.subplot(2, 3, 6)
sns.distplot(np.array(sample_mean['1000sam_with_1000ele']))
plt.title('1000sam_with_1000ele')
# Out:
# Text(0.5, 1.0, '1000sam_with_1000ele')

# %%
for i, key in enumerate(sample_mean.keys()):
    print(key, np.mean(sample_mean[key]))
# Out:
# 100sam_with_50ele 38.5652
# 1000sam_with_50ele 38.731539999999995
# 100sam_with_100ele 38.7734
# 1000sam_with_100ele 38.64389
# 100sam_with_1000ele 38.67922000000001
# 1000sam_with_1000ele 38.642902

# %%
print('Actual Mean: ', df.iloc[:,0].mean())
# Out:
# Actual Mean:  38.64358543876172

# %%
def fun_std(n_sample, m_element):
    std = []
    for i in range(0, n_sample):
        samples = random.sample(range(0, df.shape[0]), m_element)
        means.append(df.iloc[samples, 0].std())
    return std

# %%
sample_std = {}

sample_std['100sam_with_50ele'] = fun(100, 50)
sample_std['1000sam_with_50ele'] = fun(1000, 50)

sample_std['100sam_with_100ele'] = fun(100, 100)
sample_std['1000sam_with_100ele'] = fun(1000, 100)

sample_std['100sam_with_1000ele'] = fun(100, 1000)
sample_std['1000sam_with_1000ele'] = fun(1000, 1000)

# %%
plt.figure(figsize=(12, 6))
plt.subplots_adjust(hspace=0.4, wspace=0.7)

plt.subplot(2, 3, 1)
sns.distplot(np.array(sample_std['100sam_with_50ele']))
plt.title('100sam_with_50ele')

plt.subplot(2, 3, 2)
sns.distplot(np.array(sample_std['100sam_with_100ele']))
plt.title('100sam_with_100ele')

plt.subplot(2, 3, 3)
sns.distplot(np.array(sample_std['100sam_with_1000ele']))
plt.title('100sam_with_1000ele')

plt.subplot(2, 3, 4)
sns.distplot(np.array(sample_std['1000sam_with_50ele']))
plt.title('1000sam_with_50ele')

plt.subplot(2, 3, 5)
sns.distplot(np.array(sample_std['1000sam_with_100ele']))
plt.title('1000sam_with_100ele')

plt.subplot(2, 3, 6)
sns.distplot(np.array(sample_std['1000sam_with_1000ele']))
plt.title('1000sam_with_1000ele')
# Out:
# Text(0.5, 1.0, '1000sam_with_1000ele')
